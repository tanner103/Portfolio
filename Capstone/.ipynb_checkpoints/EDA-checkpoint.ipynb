# %%
#Import needed libraires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#read in data
df = pd.read_csv('./data/df.csv', index_col=None, header=0)
df = df.dropna()
df.head()
# Out:
#                 PLAYER TEAM   AGE    GP     W     L     MIN     PTS    FGM  \
# 0      AJ Hammons_2017  DAL  24.0  22.0   4.0  18.0   163.0    48.0   17.0
# 1    Aaron Brooks_2017  IND  32.0  65.0  36.0  29.0   894.0   322.0  121.0
# 2    Aaron Gordon_2017  ORL  21.0  80.0  29.0  51.0  2298.0  1019.0  393.0
# 3  Aaron Harrison_2017  CHA  22.0   5.0   2.0   3.0    17.0     1.0    0.0
# 4   Adreian Payne_2017  MIN  26.0  18.0   5.0  13.0   135.0    63.0   23.0
#
#      FGA  ...   TOV   STL   BLK     PF      FP  DD2  TD3    +/-  All-Star  \
# 0   42.0  ...  10.0   1.0  13.0   21.0   129.2  0.0  0.0   -5.0       0.0
# 1  300.0  ...  66.0  25.0   9.0   93.0   628.3  0.0  0.0  -32.0       0.0
# 2  865.0  ...  89.0  65.0  40.0  172.0  1956.0  7.0  0.0 -163.0       0.0
# 3    4.0  ...   0.0   0.0   0.0    2.0     9.1  0.0  0.0   -5.0       0.0
# 4   54.0  ...   8.0   8.0   7.0   32.0   150.1  0.0  0.0    8.0       0.0
#
#    YEAR
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017
#
# ...

# %% [markdown]
# $$Data Dictionary$$
#
# | Abbreviation | Definition |
# |---|---|
# |GP |Games Played
# |W |Wins
# |L |Losses
# |MIN |Minutes Played
# |FGM |Field Goals Made
# |FGA |Field Goals Attempted
# |FG% |Field Goal Percentage
# |3PM |3 Point Field Goals Made
# |3PA |3 Point Field Goals Attempted
# |3P% |3 Point Field Goals Percentage
# |FTM |Free Throws Made
# |FTA |Free Throws Attempted
# |FT% |Free Throw Percentage
# |OREB |Offensive Rebounds
# |DREB |Defensive Rebounds
# |REB |Rebounds AST Assists
# |TOV |Turnovers
# |STL |Steals
# |BLK |Blocks
# |PF |Personal Fouls
# |FP |Fantasy Points
# |DD2 |Double doubles
# |TD3 |Triple doubles
# |PTS |Points
# |+/- |Plus Minus Ratio

# %%
#Shape of the data
df.shape
# Out:
# (8946, 31)

# %%
#Mean of the Data
df.mean()
# Out:
# AGE           27.086762
# GP            53.201476
# W             26.562276
# L             26.639199
# MIN         1249.297853
# PTS          515.023256
# FGM          192.341123
# FGA          424.875783
# FG%           43.489926
# 3PM           36.394902
# 3PA          102.133274
# 3P%           24.092151
# FTM           93.946109
# FTA          124.102415
# FT%           70.019365
# OREB          57.471713
# DREB         161.660555
# REB          219.132267
# AST          112.909213
# TOV           71.458408
# STL           39.229875
# BLK           25.292487
# PF           108.614490
# FP          1069.454472
# DD2            4.389758
# TD3            0.107223
# +/-           -0.338663
# All-Star       0.054773
# YEAR        2010.352001
# dtype: float64

# %%
df.head()
# Out:
#                 PLAYER TEAM   AGE    GP     W     L     MIN     PTS    FGM  \
# 0      AJ Hammons_2017  DAL  24.0  22.0   4.0  18.0   163.0    48.0   17.0
# 1    Aaron Brooks_2017  IND  32.0  65.0  36.0  29.0   894.0   322.0  121.0
# 2    Aaron Gordon_2017  ORL  21.0  80.0  29.0  51.0  2298.0  1019.0  393.0
# 3  Aaron Harrison_2017  CHA  22.0   5.0   2.0   3.0    17.0     1.0    0.0
# 4   Adreian Payne_2017  MIN  26.0  18.0   5.0  13.0   135.0    63.0   23.0
#
#      FGA  ...   TOV   STL   BLK     PF      FP  DD2  TD3    +/-  All-Star  \
# 0   42.0  ...  10.0   1.0  13.0   21.0   129.2  0.0  0.0   -5.0       0.0
# 1  300.0  ...  66.0  25.0   9.0   93.0   628.3  0.0  0.0  -32.0       0.0
# 2  865.0  ...  89.0  65.0  40.0  172.0  1956.0  7.0  0.0 -163.0       0.0
# 3    4.0  ...   0.0   0.0   0.0    2.0     9.1  0.0  0.0   -5.0       0.0
# 4   54.0  ...   8.0   8.0   7.0   32.0   150.1  0.0  0.0    8.0       0.0
#
#    YEAR
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017
#
# ...

# %%
#Playing with Min, max to see worst in best player over last 20 years given '+/-'
df['+/-'].max()
# Out:
# 1072.0

# %%
df[df['+/-'] == 1072.0]
# Out:
#                    PLAYER TEAM   AGE    GP     W    L     MIN     PTS    FGM  \
# 1480  Draymond Green_2016  GSW  26.0  81.0  73.0  8.0  2808.0  1131.0  401.0
#
#         FGA  ...    TOV    STL    BLK     PF      FP   DD2   TD3     +/-  \
# 1480  819.0  ...  259.0  119.0  113.0  240.0  3387.8  33.0  13.0  1072.0
#
#       All-Star  YEAR
# 1480       1.0  2016
#
# [1 rows x 31 columns]

# %%
df['+/-'].min()
# Out:
# -684.0

# %%
df[df['+/-'] == -684.0]
# Out:
#                 PLAYER TEAM   AGE    GP     W     L     MIN    PTS    FGM  \
# 1748  Roy Hibbert_2016  LAL  29.0  81.0  17.0  64.0  1878.0  481.0  182.0
#
#         FGA  ...   TOV   STL    BLK     PF      FP  DD2  TD3    +/-  All-Star  \
# 1748  411.0  ...  76.0  32.0  110.0  252.0  1451.1  3.0  0.0 -684.0       0.0
#
#       YEAR
# 1748  2016
#
# [1 rows x 31 columns]

# %%
#Used this to look at very specific players
df[df['PLAYER'].str.contains('Harden',regex = False)].sort_values("YEAR")
# Out:
#                  PLAYER TEAM   AGE    GP     W     L     MIN     PTS    FGM  \
# 4339  James Harden_2010  OKC  20.0  76.0  47.0  29.0  1738.0   753.0  233.0
# 3902  James Harden_2011  OKC  21.0  82.0  55.0  27.0  2189.0   998.0  298.0
# 5250  James Harden_2012  OKC  22.0  62.0  44.0  18.0  1946.0  1044.0  309.0
# 6631  James Harden_2013  HOU  23.0  78.0  43.0  35.0  2985.0  2023.0  585.0
# 2027  James Harden_2014  HOU  24.0  73.0  48.0  25.0  2777.0  1851.0  549.0
# 2512  James Harden_2015  HOU  25.0  81.0  56.0  25.0  2981.0  2217.0  647.0
# 1543  James Harden_2016  HOU  26.0  82.0  41.0  41.0  3125.0  2376.0  710.0
# 194   James Harden_2017  HOU  27.0  81.0  54.0  27.0  2947.0  2356.0  674.0
# 8022  James Harden_2018  HOU  28.0  72.0  59.0  13.0  2551.0  2191.0  651.0
# 8609  James Harden_2019  HOU  29.0  78.0  51.0  27.0  2867.0  2818.0  843.0
#
#          FGA  ...    TOV    STL   BLK     PF      FP   DD2   TD3    +/-  \
# ...

# %%
#Look at FTA data
round(df['FTA'].describe(),2)
# Out:
# count    8944.00
# mean      124.10
# std       134.11
# min         0.00
# 25%        26.00
# 50%        81.00
# 75%       178.00
# max       972.00
# Name: FTA, dtype: float64

# %%
#Graph FTA vs MIN highlighting All-Stars
plt.figure(figsize = (10, 8))
sns.scatterplot(y=df['FTA'],x = df['MIN'],hue=df['All-Star'], alpha=.7) 
sns.despine();

# %%
#vuew FTA distribtuon of Non-All-Star vs All-Stars
plt.rcParams["patch.force_edgecolor"] = True
df.groupby('All-Star')['FTA'].hist(grid=False, edgecolor='#000000');

# %%
df2 = df[df['FTA'] != 0]

# %%
#FTA when taking out 0 FTA players not huge effect on means
df2.groupby('All-Star')['FTA'].mean()
# Out:
# All-Star
# 0.0    110.059300
# 1.0    438.478439
# Name: FTA, dtype: float64

# %%
#Top FTA in NBA
df[df['FTA'] >= 800][['PLAYER','FTA','GP']].sort_values('FTA')
# Out:
#                       PLAYER    FTA    GP
# 5665        Dwyane Wade_2006  803.0  75.0
# 2095       Kevin Durant_2014  805.0  81.0
# 3021   Jerry Stackhouse_2001  810.0  80.0
# 5868        Paul Pierce_2006  812.0  79.0
# 5790       LeBron James_2006  814.0  79.0
# 4291      Dwight Howard_2010  816.0  82.0
# 5780        Kobe Bryant_2006  819.0  80.0
# 2512       James Harden_2015  824.0  81.0
# 5534      Allen Iverson_2006  829.0  72.0
# 1543       James Harden_2016  837.0  82.0
# 403   Russell Westbrook_2017  840.0  81.0
# 4402       Kevin Durant_2010  840.0  82.0
# 7043      Dwight Howard_2009  849.0  79.0
# 8609       James Harden_2019  858.0  78.0
# 194        James Harden_2017  881.0  81.0
# 7492      Dwight Howard_2008  897.0  82.0
# 3843      Dwight Howard_2011  916.0  78.0
# 3176   Shaquille O'Neal_2001  972.0  74.0

# %%
#All FTA by players above 700 who are not All-Stars
df[(df['FTA'] >= 700) & (df['All-Star']==0)][['PLAYER','FTA','GP','MIN']].sort_values('FTA')
# Out:
#                     PLAYER    FTA    GP     MIN
# 5598  Carmelo Anthony_2006  709.0  80.0  2941.0
# 3126      Paul Pierce_2001  738.0  82.0  3124.0

# %%
#Looking at how many players made 0 PTS
df[df['PTS'] == 0].shape
# Out:
# (101, 31)

# %%
#Correlatoins of specific values
plt.figure(figsize = (10, 8))
sns.heatmap(df[['W','PTS','FTA','MIN', 'All-Star']].corr(),annot= True)
plt.yticks(rotation=0);

# %%
#df.PTS.hist()
sns.scatterplot(x = 'FTA',y = 'W',data = df,hue='All-Star');

# %%
#Looking at Teams sum of wins
plt.figure(figsize=(12,10))
total_wins = df.groupby('TEAM', as_index=False)['W'].sum()
sns.barplot(x='W', y='TEAM', data=total_wins.sort_values(ascending=False, by='W'))
# Out:
# <AxesSubplot:xlabel='W', ylabel='TEAM'>

# %%
#Look at the number of All-Stars per team
plt.figure(figsize=(12,10))
total_all_stars = df.groupby('TEAM', as_index=False)['All-Star'].sum()
sns.barplot(x='All-Star', y='TEAM', data=total_all_stars.sort_values(ascending=False, by='All-Star'))
# Out:
# <AxesSubplot:xlabel='All-Star', ylabel='TEAM'>

# %%
comp = pd.concat([total_wins, total_all_stars], axis=1, sort=False)

# %%
#Looking at wins vs All-Stars
sns.jointplot(x= 'W',y = 'All-Star',data=comp);

# %%
#Chart form
print(comp.sort_values('W',ascending=False)[:15])
# Out:
#    TEAM        W TEAM  All-Star
# 30  SAS  12020.0  SAS      27.0
# 7   DAL   9452.0  DAL      20.0
# 33  UTA   8779.0  UTA       8.0
# 2   BOS   8703.0  BOS      30.0
# 14  LAL   8662.0  LAL      26.0
# 12  IND   8657.0  IND      17.0
# 11  HOU   8595.0  HOU      22.0
# 16  MIA   8574.0  MIA      29.0
# 10  GSW   8526.0  GSW      18.0
# 28  POR   8424.0  POR      12.0
# 8   DEN   8342.0  DEN       8.0
# 9   DET   8052.0  DET      17.0
# 13  LAC   8000.0  LAC      14.0
# 32  TOR   7927.0  TOR      20.0
# 6   CLE   7882.0  CLE      17.0

# %%
df['FTA/MIN'] = df['FTA']/df['MIN']

# %%
#graphing FTA by FTA/MIN
sns.jointplot('FTA/MIN','FTA',data=df,hue='All-Star');
# Out:
# /Users/Tanner/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Count of All-Stars and Non-All-Stars
df['All-Star'].value_counts()
# Out:
# 0.0    8453
# 1.0     488
# Name: All-Star, dtype: int64

# %%
#FTA of Non-All-Stars
df[df['All-Star'] == 0]['FTA'].describe()
# Out:
# count    8453.000000
# mean      106.049095
# std       105.771980
# min         0.000000
# 25%        24.000000
# 50%        74.000000
# 75%       157.000000
# max       738.000000
# Name: FTA, dtype: float64

# %%
#FTA of All-Stars
df[df['All-Star'] == 1]['FTA'].describe()
# Out:
# count    488.000000
# mean     437.579918
# std      178.602991
# min        0.000000
# 25%      307.000000
# 50%      421.000000
# 75%      553.500000
# max      972.000000
# Name: FTA, dtype: float64
